# %%
keys = ["name", "age", "city"]
values = ["Tanishk", 18, "Alwar"]
my_dict = dict(zip(keys, values))
print(my_dict)
# Out:
# {'name': 'Tanishk', 'age': 18, 'city': 'Alwar'}

# %%
num1 = input("first number: ")
num2 = input("second number: ")

if num1 == num2:
    print("Both numbers are equal.")
elif num1 > num2:
    print(f"{num1} is greater than {num2}.")
else:
    print(f"{num1} is less than {num2}.")
# Out:
# first number: 23
# second number: 56
# 23 is less than 56.

# %%
my_list=[1,"my",2,"name",3,"is",4,"tanishk",5,"mamodia"]
for i in my_list:
    print(i,type(i))
# Out:
# 1 <class 'int'>
# my <class 'str'>
# 2 <class 'int'>
# name <class 'str'>
# 3 <class 'int'>
# is <class 'str'>
# 4 <class 'int'>
# tanishk <class 'str'>
# 5 <class 'int'>
# mamodia <class 'str'>

# %%
A = int(input("Enter number A: "))
B = int(input("Enter number B: "))

i=0
while A % B == 0:
    A = A / B
    i += 1


if i > 0:
    print(f"A is divisible by B {i} times.")
else:
    print("A is not purely divisible by B.")
# Out:
# Enter number A: 45
# Enter number B: 2
# A is not purely divisible by B.

# %%
numbers = [5, 9, 15, 22, 30, 41, 18, 27, 50, 33,12, 8, 21, 45, 60, 71, 39, 81, 99, 66,75, 100, 7, 48, 36]

for num in numbers:
    if num % 3 == 0:
        print(f"{num} is divisible by 3.")
    else:
        print(f"{num} is not divisible by 3.")
# Out:
# 5 is not divisible by 3.
# 9 is divisible by 3.
# 15 is divisible by 3.
# 22 is not divisible by 3.
# 30 is divisible by 3.
# 41 is not divisible by 3.
# 18 is divisible by 3.
# 27 is divisible by 3.
# 50 is not divisible by 3.
# 33 is divisible by 3.
# 12 is divisible by 3.
# 8 is not divisible by 3.
# 21 is divisible by 3.
# 45 is divisible by 3.
# 60 is divisible by 3.
# 71 is not divisible by 3.
# 39 is divisible by 3.
# 81 is divisible by 3.
# 99 is divisible by 3.
# 66 is divisible by 3.
# 75 is divisible by 3.
# 100 is not divisible by 3.
# 7 is not divisible by 3.
# 48 is divisible by 3.
# 36 is divisible by 3.

# %%
my_list = [1, 2, 3, 4, 5]
sub_list = my_list[1:3]
print(sub_list)
# Out:
# [2, 3]

# %%
text = "Hello, World!"
sub_text = text[7:12]
print(sub_text)
# Out:
# World

# %%
def multiply_or_sum(a, b):
    product = a * b
    if product <= 1000:
        return product
    else:
        return a + b

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

result = multiply_or_sum(num1, num2)
print("Result:", result)
# Out:
# Enter first number: 34
# Enter second number: 56
# Result: 90

# %%
#questions given in the class

# %%
#Count the Number of Vowels in a String (Ignoring Case)
def count_vowels(s):
    vowels = "aeiouAEIOU"
    return sum(1 for char in s if char in vowels)

string = input("Enter a string: ")
print("Number of vowels:", count_vowels(string))
# Out:
# Enter a string: TANISHK mamodia
# Number of vowels: 6

# %%
#Solve a Quadratic Equation (ax² + bx + c = 0)
import math

def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return "No real roots"
    elif discriminant == 0:
        root = -b / (2*a)
        return f"One root: {root}"
    else:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        return f"Roots: {root1}, {root2}"

a = float(input("Enter coefficient a: "))
b = float(input("Enter coefficient b: "))
c = float(input("Enter coefficient c: "))
print(solve_quadratic(a, b, c))
# Out:
# Enter coefficient a: 1
# Enter coefficient b: 2
# Enter coefficient c: 3
# No real roots

# %%
#Calculate Distance Between Two Points in a 2D Plane
import math

def distance(x1, y1, x2, y2):
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

x1, y1 = map(float, input("Enter x1, y1: ").split())
x2, y2 = map(float, input("Enter x2, y2: ").split())

print("Distance between points:", distance(x1, y1, x2, y2))
# Out:
# Enter x1, y1: 2.3 4.5
# Enter x2, y2: 5.6 8.9
# Distance between points: 5.5

# %%
#Text Analysis (Number of Words, Sentences, etc.)
from collections import Counter
import re

def text_analysis(text):
    words = re.findall(r'\b\w+\b', text)
    sentences = re.split(r'[.!?]', text)
    most_frequent = Counter(words).most_common(1)

    return {
        "Word Count": len(words),
        "Sentence Count": len(sentences) - 1,
        "Average Word Length": sum(len(word) for word in words) / len(words) if words else 0,
        "Most Frequent Word": most_frequent[0][0] if most_frequent else None
    }

text = input("Enter text: ")
result = text_analysis(text)
for key, value in result.items():
    print(f"{key}: {value}")
# Out:
# Enter text: tanishk mamodia
# Word Count: 2
# Sentence Count: 0
# Average Word Length: 7.0
# Most Frequent Word: tanishk

# %%
#String Compression (Run-Length Encoding)
def compress_string(s):
    compressed = []
    count = 1

    for i in range(1, len(s)):
        if s[i] == s[i - 1]:
            count += 1
        else:
            compressed.append(s[i - 1] + str(count))
            count = 1

    compressed.append(s[-1] + str(count))  # Append last character count
    return ''.join(compressed)

string = input("Enter a string: ")
print("Compressed string:", compress_string(string))
# Out:
# Enter a string: tanishk mamodia
# Compressed string: t1a1n1i1s1h1k1 1m1a1m1o1d1i1a1
