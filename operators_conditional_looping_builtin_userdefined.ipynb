# %%
print("hello world")
# Out:
# hello world

# %%
name = "tanishk"
age = 19
print(f"my name is {name} and my age is {age}")
# Out:
# my name is tanishk and my age is 19

# %%
name="angad"
age=20
print("my name is "+name+ " and i am "+str(age)+" years old"  )
# Out:
# my name is angad and i am 20 years old

# %%
name ="shvm"
age =19
print("my name is {} and i am {} years old".format(name,age))
# Out:
# my name is shvm and i am 19 years old

# %%
import sys
sys.stdout.write("hello world !\n")
# Out:
# hello world !

# %%
with open("output.txt","w") as file:
  file.write("my fav singer is virat kholi")

# %%
with open("output.txt","a") as file:
  file.write("\nballe balle")

# %%
user_input = input("Please enter something: ")
print("You entered: ", user_input)
# Out:
# Please enter something: tanishk
# You entered:  tanishk

# %%
with open('output.txt', 'r') as f:
 data=f.read()
print(data)
# Out:
# my fav singer is virat kholi
# balle balle

# %%
 a = 18
 b = 24
 print(a + b)
 print(a - b)
 print(a * b)
 print(a / b)
 print(a % b)
 print(a ** b)
 print(a // b)
# Out:
# 42
# -6
# 432
# 0.75
# 18
# 1338258845052394702439737982976
# 0

# %%
 a = True
 b = False
 print(a and b)
 print(a or b)
 print(not a)
# Out:
# False
# True
# False

# %%
 a = 49
 b = 21
 print(a == b)
 print(a != b)
 print(a > b)
 print(a < b)
 print(a >= b)
 print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
a = [11, 12, 23, 44, 65]
print(11 in a)
print(9 in a)
print(12 not in a)
print(5 not in a)
# Out:
# True
# False
# False
# True

# %%
a = 60
b = 60
print(a is b)
print(a is not b)
# Out:
# True
# False

# %%
a = -30
if a > 0:
 print("a is positive")

# %%
a = 30
if a > 0:
 print("a is positive")
# Out:
# a is positive

# %%
a = -40
if a > 0:
 print("a is positive")
else:
 print("a is not positive")
# Out:
# a is not positive

# %%
a = 30
if a > 30:
 print("a is GREATER THAN 30")
elif a < 30:
 print("a is LESS THAN 30")
else:
 print("a = 30 ")
# Out:
# a = 30

# %%
a = 10
if a >= 0:
   if a == 0:
    print("a is zero")
   else:
    print("a is positive")
else:
 print("a is negative")
# Out:
# a is positive

# %%
for i in [13, 22, 23, 14, 65]:
 print(i)
# Out:
# 13
# 22
# 23
# 14
# 65

# %%
i = 5
while i <= 10:
  print(i)
  i += 1
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
for i in range(3, 6):
   for j in range(3, 6):
     print(i, j)
# Out:
# 3 3
# 3 4
# 3 5
# 4 3
# 4 4
# 4 5
# 5 3
# 5 4
# 5 5

# %%
my_list = [3, 2, 1, "SALMAN", "KHAN"]

# %%
print(my_list[0])
print(my_list[-1])
# Out:
# 3
# KHAN

# %%
my_list[1] = "HI"
print(my_list) #TO CHANGE
# Out:
# [3, 'HI', 1, 'SALMAN', 'KHAN']

# %%
my_list.append("DELHI")
print(my_list)

my_list.insert(1, "BIHAR")
print(my_list)
# Out:
# [3, 'HI', 1, 'SALMAN', 'KHAN', 'DELHI']
# [3, 'BIHAR', 'HI', 1, 'SALMAN', 'KHAN', 'DELHI']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b9e944dca251> in <cell line: 0>()
# ----> 1 my_list.sort()
#       2 print(my_list)
#       3 my_list.sort(reverse=True)
#       4 print(my_list)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
my_tuple = ('TANISHK', 'MAMODIA', 'HERO')
print(my_tuple)
# Out:
# ('TANISHK', 'MAMODIA', 'HERO')

# %%
print(my_tuple[0])
print(my_tuple[1])
print(my_tuple[2])
# Out:
# TANISHK
# MAMODIA
# HERO

# %%
my_tuple = my_tuple + ('HAI',)
print(my_tuple)
# Out:
# ('TANISHK', 'MAMODIA', 'HERO', 'HAI')

# %%
del my_tuple

# %%
my_set = {'RAJASTHAN', 'DELHI', 'HARYANA'}
print(my_set)
# Out:
# {'RAJASTHAN', 'HARYANA', 'DELHI'}

# %%
print('HARYANA' in my_set)
# Out:
# True

# %%
my_set.add('PUNJAB')
print(my_set)

my_set.remove('DELHI')
print(my_set)
# Out:
# {'RAJASTHAN', 'HARYANA', 'PUNJAB', 'DELHI'}
# {'RAJASTHAN', 'HARYANA', 'PUNJAB'}

# %%
del my_set

# %%
my_dict = {'name': 'KAMLESH', 'age': 21, 'city': 'BIHAR'}
print(my_dict)
# Out:
# {'name': 'KAMLESH', 'age': 21, 'city': 'BIHAR'}

# %%
print(my_dict['name'])
print(my_dict['age'])
print(my_dict['city'])
# Out:
# KAMLESH
# 21
# BIHAR

# %%
my_dict['job'] = 'MANAGER'
print(my_dict)



my_dict['age'] = 25
print(my_dict)



del my_dict['job']
print(my_dict)
# Out:
# {'name': 'KAMLESH', 'age': 21, 'city': 'BIHAR', 'job': 'MANAGER'}
# {'name': 'KAMLESH', 'age': 25, 'city': 'BIHAR', 'job': 'MANAGER'}
# {'name': 'KAMLESH', 'age': 25, 'city': 'BIHAR'}

# %%
my_dict = {'name': 'KAMLESH', 'age': 25, 'city': 'BIHAR'}
for key in my_dict:
 print(key)
 print('----------')

for value in my_dict.values():
 print(value)
 print('----------')


for key, value in my_dict.items():
 print(key, value)
 print('----------')
# Out:
# name
# ----------
# age
# ----------
# city
# ----------
# KAMLESH
# ----------
# 25
# ----------
# BIHAR
# ----------
# name KAMLESH
# ----------
# age 25
# ----------
# city BIHAR
# ----------

# %%
del my_dict

# %%
#one arguement
def even_odd(num):
  if num%2==0:
    print("the number is even")
  else:
      print("the number is odd")

even_odd(33)
# Out:
# the number is odd

# %%
#two arguement
def add_numbers(num1, num2):
 result = num1 + num2
 print(result)
add_numbers(34,55)
# Out:
# 89

# %%
def multiply_numbers(num1, num2):
 result = num1 * num2
 return result

product = multiply_numbers(55, 85)
print(product)
# Out:
# 4675

# %%
import math

help(math) #important

print('------------------------')
print(math.cbrt(4))
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
import math as tanishk

help(tanishk) #important

print('------------------------')
print(tanishk.cbrt(4))
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
# %%writefile my_calculator.py
def add(x,y):
  return x+y

def sub(x,y):
  return x-y

def mult(x,y):
  return x*y

def div(x,y):
  if y==0:
    return "error division by 0 "
  else:
     return x/y
# Out:
# Overwriting my_calculator.py

# %%
import my_calculator
help(my_calculator)
print("---------------------")

result_add = my_calculator.add(8,8)
result_sub = my_calculator.sub(8,8)
result_mult = my_calculator.mult(8,8)
result_div = my_calculator.div(8,8)

print("Addition:",result_add)
print("Subtraction:",result_sub)
print("Multiplication:",result_mult)
print("Division: ",result_div)
# Out:
# Help on module my_calculator:
#
# NAME
#     my_calculator
#
# FUNCTIONS
#     add(x, y)
#
#     div(x, y)
#
#     mult(x, y)
#
#     sub(x, y)
#
# FILE
#     /content/my_calculator.py
#
#
# ---------------------
# Addition: 16
# Subtraction: 0
# Multiplication: 64
# Division:  1.0

# %%
def addi(a,b):
  return a+b
addi(5,5)
# Out:
# 10

# %%
plus=lambda a,b:a+b
plus(5,5)
# Out:
# 10

# %%
def even_or_odd(num):
  if num%2==0:
    return "the number {} is even".format(num)
  else:
    return "the number {} is odd".format(num)
even_or_odd(24)

lst=[1,2,3,4,5,6,7,8,9,24,56,78]
print(list(map(even_or_odd,lst)) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-192d6812c0ba> in <cell line: 0>()
#       7
#       8 lst=[1,2,3,4,5,6,7,8,9,24,56,78]
# ----> 9 print(list(map(even_or_odd,lst)) )
#
# TypeError: 'list' object is not callable
