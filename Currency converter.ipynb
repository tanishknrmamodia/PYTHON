# %%
  rates = {
    'USD': {'INR': 83.45, 'EUR': 0.91, 'GBP': 0.76, 'JPY': 150.32},
    'INR': {'USD': 0.012, 'EUR': 0.011, 'GBP': 0.0091, 'JPY': 1.80},
    'EUR': {'USD': 1.10, 'INR': 89.05, 'GBP': 0.84, 'JPY': 164.20},
    'GBP': {'USD': 1.31, 'INR': 110.20, 'EUR': 1.19, 'JPY': 195.30},
    'JPY': {'USD': 0.0067, 'INR': 0.56, 'EUR': 0.0061, 'GBP': 0.0051}
}

print("\n welcome to the world of Currencies converter by TANISHK : USD, INR, EUR, GBP, JPY\n")

base = input("Enter currency you have to covert: ").upper()
target = input("Enter in which currency you want : ").upper()

if base in rates and target in rates[base]:
    amount = float(input("Enter amount to convert: "))
    result = amount * rates[base][target]
    print(f"\n {amount} {base} = {result:.2f} {target}\n")
else:
    print("\n this currency conversion in not available by tanishk .\n")
# Out:
#  welcome to the world of Currencies converter by TANISHK : USD, INR, EUR, GBP, JPY
#
# Enter currency you have to covert: usd
# Enter in which currency you want : inr
# Enter amount to convert: 56
#
#  56.0 USD = 4673.20 INR
